# %% [markdown]
# <a href="https://colab.research.google.com/github/mrrajeev29/Virat-Kohli-Career-Analysis/blob/main/Virat_Kohli_Career_Ananlysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/final (1).csv')

# %%
data
# Out:
#      index  runs  opponent        ground       date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
#
# [516 rows x 8 columns]
# ...

# %%
data.head()
# Out:
#    index  runs  opponent        ground       date match  Match_No  total
# 0      0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1      1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2      2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3      3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4      4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159

# %%
data.tail()
# Out:
#      index  runs opponent      ground       date match  Match_No  total
# 511    535    11  England  Birmingham   1Jul2022  Test       512  23661
# 512    536    20  England  Birmingham   1Jul2022  Test       513  23681
# 513    537     1  England  Birmingham   9Jul2022   T20       514  23682
# 514    538    11  England  Nottingham  10Jul2022   T20       515  23693
# 515    539    16  England      Lord's  14Jul2022   ODI       516  23709

# %%
data.size
# Out:
# 4128

# %%
data.index
# Out:
# RangeIndex(start=0, stop=516, step=1)

# %%
data.shape
# Out:
# (516, 8)

# %%
data.isnull()
# Out:
#      index   runs  opponent  ground   date  match  Match_No  total
# 0    False  False     False   False  False  False     False  False
# 1    False  False     False   False  False  False     False  False
# 2    False  False     False   False  False  False     False  False
# 3    False  False     False   False  False  False     False  False
# 4    False  False     False   False  False  False     False  False
# ..     ...    ...       ...     ...    ...    ...       ...    ...
# 511  False  False     False   False  False  False     False  False
# 512  False  False     False   False  False  False     False  False
# 513  False  False     False   False  False  False     False  False
# 514  False  False     False   False  False  False     False  False
# 515  False  False     False   False  False  False     False  False
#
# [516 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# index       0
# runs        0
# opponent    0
# ground      0
# date        0
# match       0
# Match_No    0
# total       0
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of      index  runs  opponent        ground       date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
#
# [516 rows x 8 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      index  runs  opponent        ground       date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18Aug2008   ODI         1     12
# 1        1    37  SriLanka      Dambulla  20Aug2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24Aug2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27Aug2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29Aug2008   ODI         5    159
# ..     ...   ...       ...           ...        ...   ...       ...    ...
# 511    535    11   England    Birmingham   1Jul2022  Test       512  23661
# 512    536    20   England    Birmingham   1Jul2022  Test       513  23681
# 513    537     1   England    Birmingham   9Jul2022   T20       514  23682
# 514    538    11   England    Nottingham  10Jul2022   T20       515  23693
# 515    539    16   England        Lord's  14Jul2022   ODI       516  23709
#
# [516 rows x 8 columns]>

# %%
Total_run=sum(data['runs'])
print('Total Run = ',Total_run)
# Out:
# Total Run =  23709

# %%
Total_odi_match_innings=0
Total_T20_match_innings=0
Total_Test_match_innings=0
for i in data['match']:
  if i=='ODI':
    Total_odi_match_innings+=1
  if i=='T20':
    Total_T20_match_innings+=1
  if i=='Test':
    Total_Test_match_innings+=1
print('Total_odi_match_innings ',Total_odi_match_innings)
print('Total_T20_match_innings ',Total_T20_match_innings)
print('Total_Test_match_innings ',Total_Test_match_innings)
# Out:
# Total_odi_match_innings  252
# Total_T20_match_innings  91
# Total_Test_match_innings  173

# %%
#Run Against Pak
run=0
match=0
for i in range(data.shape[0]):
  if data['opponent'][i]=='Pakistan':
    run+=data['runs'][i]
    match+=1
print('Run against Pakistan',run,'in',match,'matches')
# Out:
# Run against Pakistan 847 in 20 matches

# %%
l=list(set(data['opponent']))
print('Opponents = \n')
l
# Out:
# Opponents =
# ['Afghanistan',
#  'Zimbabwe',
#  'SriLanka',
#  'Ireland',
#  'Pakistan',
#  'England',
#  'SouthAfrica',
#  'NewZealand',
#  'U.A.E.',
#  'Bangladesh',
#  'Australia',
#  'WestIndies',
#  'Netherlands',
#  'Scotland']

# %%
Runs=[]

# %%
def Run_against_particular_team(teams):
  run=0
  match=0
  for i in range(data.shape[0]):
    if data['opponent'][i]==teams:
      run+=data['runs'][i]
      match+=1
  Runs.append(run)
  print('Total Run againsts',teams,'teams',run,'in',match,'matches')

# %%
for country in l:
  Run_against_particular_team(country)
# Out:
# Total Run againsts Afghanistan teams 117 in 2 matches
# Total Run againsts Zimbabwe teams 279 in 7 matches
# Total Run againsts SriLanka teams 3644 in 70 matches
# Total Run againsts Ireland teams 87 in 4 matches
# Total Run againsts Pakistan teams 847 in 20 matches
# Total Run againsts England teams 3903 in 103 matches
# Total Run againsts SouthAfrica teams 2893 in 61 matches
# Total Run againsts NewZealand teams 2555 in 57 matches
# Total Run againsts U.A.E. teams 33 in 1 matches
# Total Run againsts Bangladesh teams 1201 in 21 matches
# Total Run againsts Australia teams 4483 in 95 matches
# Total Run againsts WestIndies teams 3653 in 73 matches
# Total Run againsts Netherlands teams 12 in 1 matches
# Total Run againsts Scotland teams 2 in 1 matches

# %%
p=list(set(data['ground']))
print('Ground = \n')
p
# Out:
# Ground =
# ['Hobart',
#  'CapeTown',
#  'Chennai',
#  'Bulawayo',
#  'Perth',
#  'Sydney',
#  'Wellington',
#  'Dubai(DSC)',
#  'PortofSpain',
#  'Leeds',
#  'Ahmedabad',
#  'Dambulla',
#  'Vadodara',
#  'Southampton',
#  'Kolkata',
#  'Bengaluru',
#  'Cardiff',
#  'Pune',
#  'Birmingham',
#  'Brabourne',
#  'TheOval',
#  "Lord's",
#  'Cuttack',
#  'Guwahati',
#  'Visakhapatnam',
#  'Manchester',
#  'Kingston',
#  'Colombo(RPS)',
#  'Bristol',
#  'Thiruvananthapuram',
#  'Harare',
#  'Nottingham',
#  'GrosIslet',
#  'Gqeberha',
#  'MountMaunganui',
#  'Hambantota',
#  'Kochi',
#  'Hamilton',
#  'Durban',
#  'Centurion',
#  'Fatullah',
#  'Dublin(Malahide)',
#  'Providence',
#  'Kanpur',
#  'Hyderabad(Deccan)',
#  'Nagpur',
#  'Wankhede',
#  'Pallekele',
#  'Christchurch',
#  'Melbourne',
#  'Indore',
#  'Dharamsala',
#  'Brisbane',
#  'Napier',
#  'Galle',
#  'Colombo(SSC)',
#  'Canberra',
#  'Johannesburg',
#  'Rajkot',
#  'Adelaide',
#  'Colombo(PSS)',
#  'Roseau',
#  'Mirpur',
# ...

# %%
def Runs_on_particular_Ground(Ground):
  run=0
  match=0
  for i in range(data.shape[0]):
    if data['ground'][i]==Ground:
      run+=data['runs'][i]
      match+=1
  print('Total Runs on',Ground,'ground',run,'in',match,'matches')

# %%
for ground in p:
  Runs_on_particular_Ground(ground)
# Out:
# Total Runs on Hobart ground 133 in 1 matches
# Total Runs on CapeTown ground 394 in 7 matches
# Total Runs on Chennai ground 620 in 14 matches
# Total Runs on Bulawayo ground 82 in 2 matches
# Total Runs on Perth ground 501 in 9 matches
# Total Runs on Sydney ground 652 in 17 matches
# Total Runs on Wellington ground 257 in 6 matches
# Total Runs on Dubai(DSC) ground 68 in 3 matches
# Total Runs on PortofSpain ground 585 in 10 matches
# Total Runs on Leeds ground 180 in 5 matches
# Total Runs on Ahmedabad ground 494 in 17 matches
# Total Runs on Dambulla ground 243 in 10 matches
# Total Runs on Vadodara ground 93 in 2 matches
# Total Runs on Southampton ground 322 in 9 matches
# Total Runs on Kolkata ground 788 in 18 matches
# Total Runs on Bengaluru ground 485 in 17 matches
# Total Runs on Cardiff ground 243 in 5 matches
# Total Runs on Pune ground 762 in 12 matches
# Total Runs on Birmingham ground 633 in 13 matches
# Total Runs on Brabourne ground 16 in 1 matches
# ...

# %%
def Runs_in_particular_year(year):
  run=0
  match=0
  for i in range(data.shape[0]):
    if data['date'][i][-4:]==year:
      run+=data['runs'][i]
      match+=1
  print('Total Runs in',year,'year',run,'in',match,'matches')

# %%
for year in range(2008,2023):
  Runs_in_particular_year(str(year))
# Out:
# Total Runs in 2008 year 159 in 5 matches
# Total Runs in 2009 year 325 in 8 matches
# Total Runs in 2010 year 1021 in 25 matches
# Total Runs in 2011 year 1644 in 47 matches
# Total Runs in 2012 year 2186 in 46 matches
# Total Runs in 2013 year 1913 in 43 matches
# Total Runs in 2014 year 2286 in 47 matches
# Total Runs in 2015 year 1307 in 37 matches
# Total Runs in 2016 year 2595 in 41 matches
# Total Runs in 2017 year 2818 in 52 matches
# Total Runs in 2018 year 2735 in 47 matches
# Total Runs in 2019 year 2455 in 46 matches
# Total Runs in 2020 year 842 in 24 matches
# Total Runs in 2021 year 964 in 30 matches
# Total Runs in 2022 year 459 in 18 matches

# %%
plt.hist(data['opponent'])
plt.title('Histogram for Terrorism attack year wise.')
plt.xlabel('Year Of Terrorism attack')
plt.ylabel('Number of terrorism attack')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='opponent',data=data,palette='crest')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.title('Number of Matches against each opponent by King Kohli',size=20)
plt.ylabel('Number of matches')
# Out:
# Text(0, 0.5, 'Number of matches')

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='ground',data=data,palette='crest')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.title('Number of Matches on each ground by King Kohli',size=20)
plt.ylabel('Number of matches')
# Out:
# Text(0, 0.5, 'Number of matches')

# %%
plt.figure(figsize=(60,5))
ax = sns.countplot(x='opponent',data=data,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('opponents vs No. of matches',size=20)
plt.ylabel('Matches')
# Out:
# Text(0, 0.5, 'Matches')

# %%
plt.figure(figsize=(60,5))
ax = sns.countplot(x='ground',data=data,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('Grounds vs No. of matches',size=20)
plt.ylabel('Matches')
# Out:
# Text(0, 0.5, 'Matches')

# %%
plt.figure(figsize=(20,50))
sns.boxplot(x=data['runs'],y=data['opponent'])
# Out:
# <Axes: xlabel='runs', ylabel='opponent'>

# %%
pd.crosstab(data.opponent, data.runs).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Runs against each team',fontsize=25)
plt.ylabel('Area',fontsize=20)
plt.xlabel("Opponents",fontsize=20)
plt.show()

# %%
city_counts = data['opponent'].value_counts().to_frame().sort_values('opponent', axis=0, ascending=False).head(10)

fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(city_counts.index, city_counts['opponent'], color=['cyan'], width=0.5)

ax.set_title('Number of matches', fontsize=16)
ax.set_xlabel('Opponents', fontsize=14)
ax.set_ylabel('Number of matches', fontsize=14)

ax.tick_params(axis='both', labelsize=12)
ax.set_xticklabels(city_counts.index, rotation=45, ha='right')

for i, v in enumerate(city_counts['opponent']):
    ax.text(i - 0.1, v + 50, str(v), fontsize=12)

ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

plt.show()
# Out:
# <ipython-input-95-e2027c6ec30a>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(city_counts.index, rotation=45, ha='right')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

oppo = data.opponent.dropna(False)

plt.subplots(figsize=(10, 10))
wordcloud = WordCloud(background_color='white', width=512, height=384).generate(' '.join(oppo))
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Opponents', fontsize=16)  # Adjust the title
plt.show()
# Out:
# <ipython-input-98-b1d59f7ec6a2>:4: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   oppo = data.opponent.dropna(False)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
types = data.ground.dropna(False)
plt.subplots(figsize=(10, 10))
wordcloud = WordCloud(background_color='white', width=512, height=384).generate(' '.join(types))
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Word Cloud of Attack Types', fontsize=16)  # Adjust the title
plt.show()
# Out:
# <ipython-input-101-dc41567aca2f>:3: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   types = data.ground.dropna(False)
